# %% [markdown]
# ## Experiment Runner
#
# Run the code cells below to run all the experiments performed for this final project. These experiements use pretrained
# models and tokenizers with a dataset to classify each observation as privileged or not privileged and provides an
# explanation for each prediction.
#
# Use Google Colab GPUs to leverage the compute resources and run the experiments efficiently.
#
# Before running the notebook, copy this project folder into Google Drive as `MyDrive/NLP_Final_Project` so Colab can access
# the code, dataset, and requirements file.

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

PROJECT_DIR = '/content/drive/MyDrive/NLP_Final_Project'

if not os.path.exists(PROJECT_DIR):
    raise FileNotFoundError(
        f'Project folder not found: {PROJECT_DIR}. Copy the repo into Google Drive first.'
    )

os.chdir(PROJECT_DIR)
print('Current working directory:', os.getcwd())
print('Top-level files:', os.listdir())
# Out:
# Current working directory: /content/drive/MyDrive/NLP_Final_Project
# Top-level files: ['run_baselines.py', 'rename_files.py', '.gitignore', 'ModelDiagram.drawio.png', '.gitattributes', 'README.md', 'requirements.txt', 'runner.ipynb', 'models', 'preprocess', 'outputs']

# %%
import torch
print(f"torch.cuda.is_available(): {torch.cuda.is_available()}")
print(f"torch.version.cuda: {torch.version.cuda}")
# Out:
# torch.cuda.is_available(): True
# torch.version.cuda: 12.8

# %%
# %matplotlib inline

# %%
# %pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 1.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 145.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 33.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 24.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 28.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 133.8 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 4.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 133.8 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 109.4 MB/s eta 0:00:0000:0100:01
# ...

# %%
# Experiment 1: BERT baseline with default settings for a fast 1-epoch reference run
# !python models/bert_baseline.py --output_dir outputs/bert_baseline_default_1epoch --epochs 1
# Out:
# 2026-05-01 13:24:28.685971: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-01 13:24:28.750602: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading the data...
# Size of the loaded dataset:
#  - train: 414670
#  - val: 34493
#  - test: 68238
# Loading the tokenizer and pretrained model...
# tokenizer_config.json: 100% 48.0/48.0 [00:00<00:00, 279kB/s]
# ...

# %%
# Experiment 2: BERT with a smaller training subset to check whether faster iterations still learn anything
# !python models/bert_baseline.py --output_dir outputs/bert_baseline_train10k --epochs 1 --train_size 10000 --batch_size 8 --learning_rate 2e-5
# Out:
# 2026-05-01 14:44:26.523404: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-01 14:44:26.587919: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading the data...
# Size of the loaded dataset:
#  - train: 414670
#  - val: 34493
#  - test: 68238
# Loading the tokenizer and pretrained model...
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# ...

# %%
# Experiment 3: BERT with a larger training subset while keeping the run at 1 epoch
# !python models/bert_baseline.py --output_dir outputs/bert_baseline_train45k --epochs 1 --train_size 45000 --batch_size 8 --learning_rate 2e-5
# Out:
# 2026-05-01 15:59:56.795125: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-01 15:59:56.862716: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading the data...
# Size of the loaded dataset:
#  - train: 414670
#  - val: 34493
#  - test: 68238
# Loading the tokenizer and pretrained model...
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# ...

# %%
# Experiment 4: BERT with a lower learning rate to see if it improves minority-class recall
# !python models/bert_baseline.py --output_dir outputs/bert_baseline_lr1e5 --epochs 1 --batch_size 8 --learning_rate 1e-5
# Out:
# 2026-05-01 17:23:48.616851: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-01 17:23:48.683207: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading the data...
# Size of the loaded dataset:
#  - train: 414670
#  - val: 34493
#  - test: 68238
# Loading the tokenizer and pretrained model...
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# ...

# %%
# Experiment 5: RoBERTa comparison run with the same 1-epoch budget
# !python models/bert_baseline.py --output_dir outputs/bert_baseline_roberta_1epoch --model_name roberta-base --epochs 1 --batch_size 8 --learning_rate 2e-5
# Out:
# 2026-05-01 18:43:44.117733: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-01 18:43:44.184082: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading the data...
# Size of the loaded dataset:
#  - train: 414670
#  - val: 34493
#  - test: 68238
# Loading the tokenizer and pretrained model...
# tokenizer_config.json: 100% 25.0/25.0 [00:00<00:00, 172kB/s]
# ...

# %%
# !zip -r all_files_experiments.zip outputs
from google.colab import files
files.download("all_files_experiments.zip")
# Out:
# updating: outputs/ (stored 0%)
# updating: outputs/bert_baseline_default_1epoch/ (stored 0%)
# updating: outputs/bert_baseline_default_1epoch/checkpoints/ (stored 0%)
# updating: outputs/bert_baseline_default_1epoch/checkpoints/checkpoint-3750/ (stored 0%)
# updating: outputs/bert_baseline_default_1epoch/checkpoints/checkpoint-3750/config.json (deflated 48%)
# updating: outputs/bert_baseline_default_1epoch/checkpoints/checkpoint-3750/model.safetensors (deflated 7%)
# updating: outputs/bert_baseline_default_1epoch/checkpoints/checkpoint-3750/tokenizer_config.json (deflated 76%)
# updating: outputs/bert_baseline_default_1epoch/checkpoints/checkpoint-3750/special_tokens_map.json (deflated 42%)
# updating: outputs/bert_baseline_default_1epoch/checkpoints/checkpoint-3750/vocab.txt (deflated 53%)
# updating: outputs/bert_baseline_default_1epoch/checkpoints/checkpoint-3750/tokenizer.json (deflated 71%)
# ...
