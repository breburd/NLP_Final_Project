# %% [markdown]
# ## Experiment Runner
#
# Run the code cells below to run all the experiments performed for this final project. These experiements use pretrained
# models and tokenizers with a dataset to classify each observation as privileged or not privileged and provides an
# explanation for each prediction.
#
# Use Google Colab GPUs to leverage the compute resources and run the experiments efficiently.

# %%
import torch
print(f"torch.cuda.is_available(): {torch.cuda.is_available()}")
print(f"torch.version.cuda: {torch.version.cuda}")

# %%
# %matplotlib inline

# %%
# %pip install -r requirements.txt

# %%
# Run the bert_baseline with no hyperparameter tuning
# !python models/bert_baseline.py

# %%
# Run the bert_baseline with some hyperparameter tuning
# !python models/bert_baseline.py --output_dir outputs/bert_baseline_tuned --epochs 5 --batch_size 16 --learning_rate 1e-4

# %%
# Run the bert_baseline with a different pretrained model
# !python models/bert_baseline.py --output_dir outputs/bert_baseline_roberta --model_name roberta-base --epochs 5 --batch_size 16 --learning_rate 1e-4

# %%
# Zips all files in the current working directory
# !zip -r /content/outputs/all_files.zip /content/outputs*

# Save the files locally
from google.colab import files
files.download("/content/outputs/all_files.zip")
